# %%
# List of difficult img:
# /home/toto/ros_ws/src/robotic_project/vision/dataset/test/HD/blocks_group2_1.jpg
# /home/toto/ros_ws/src/robotic_project/vision/dataset/test/HD/blocks_group2_11.jpg
# /home/toto/ros_ws/src/robotic_project/vision/dataset/test/HD/blocks_group2_36.jpg

# %%
from LegoDetect import LegoDetect
from PIL import Image, ImageDraw

img_path = '/home/toto/ros_ws/src/robotic_project/vision/scripts/log/img_ZED_cam.png'
legoDetect = LegoDetect(img_path)

center_list = []
for index, lego in enumerate(legoDetect.lego_list, start=1):
    print(index)
    lego.show()
    center_list.append(lego.center_point)

# Draw center points
img = Image.open(img_path)
draw = ImageDraw.Draw(img)
draw.point(center_list, 'red')
display(img)
# Out:
# Using cache found in /home/toto/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2023-1-12 Python-3.8.10 torch-1.13.1+cu117 CPU
#
# Fusing layers...
# YOLOv5m summary: 212 layers, 20893344 parameters, 0 gradients, 48.0 GFLOPs
# Adding AutoShape...
# <PIL.Image.Image image mode=RGB size=1280x720>
# /home/toto/ros_ws/src/robotic_project/vision/dataset/test/HD/blocks_group2_1.jpg
# img size: 1280 x 720
# Draw RegionOfInterest
# x = 464 y = 552
# x = 551 y = 339
# Detecting RegionOfInterest...
# <PIL.Image.Image image mode=RGB size=1280x720>
# /home/toto/ros_ws/src/robotic_project/vision/scripts/log/img_ROI.png
# img size: 1280 x 720
# 1
# <PIL.Image.Image image mode=RGB size=70x97>
# class = X1-Y3-Z2-FILLET
# id = 6
# confidence = 0.90
# center_point = (745, 365)
# center_point_uv = (535, 365)
# --> point cloud = ()
# --> point world = ()
#
# -----------------
# 2
# <PIL.Image.Image image mode=RGB size=70x143>
# class = X1-Y2-Z2-CHAMFER
# id = 3
# confidence = 0.90
# center_point = (651, 372)
# center_point_uv = (629, 372)
# --> point cloud = ()
# --> point world = ()
#
# -----------------
# 3
# <PIL.Image.Image image mode=RGB size=70x195>
# class = X1-Y4-Z1
# id = 7
# confidence = 0.87
# center_point = (607, 383)
# center_point_uv = (673, 383)
# --> point cloud = ()
# --> point world = ()
#
# -----------------
# 4
# <PIL.Image.Image image mode=RGB size=70x89>
# class = X1-Y3-Z2-FILLET
# id = 6
# confidence = 0.82
# center_point = (790, 360)
# center_point_uv = (490, 360)
# --> point cloud = ()
# --> point world = ()
#
# -----------------
# 5
# <PIL.Image.Image image mode=RGB size=70x170>
# class = X1-Y2-Z2
# id = 2
# confidence = 0.74
# center_point = (568, 382)
# center_point_uv = (712, 382)
# --> point cloud = ()
# --> point world = ()
#
# -----------------
# 6
# <PIL.Image.Image image mode=RGB size=70x153>
# class = X1-Y3-Z2
# id = 5
# confidence = 0.70
# center_point = (684, 378)
# center_point_uv = (596, 378)
# --> point cloud = ()
# --> point world = ()
#
# -----------------
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x720>
