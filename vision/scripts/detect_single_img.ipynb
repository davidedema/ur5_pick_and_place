# %%
# List of difficult img:
# /home/toto/ros_ws/src/robotic_project/vision/dataset/test/HD/blocks_group2_1.jpg
# /home/toto/ros_ws/src/robotic_project/vision/dataset/test/HD/blocks_group2_11.jpg
# /home/toto/ros_ws/src/robotic_project/vision/dataset/test/HD/blocks_group2_36.jpg

# %%
from LegoDetect import LegoDetect
from PIL import Image, ImageDraw

img_path = '/home/toto/ros_ws/src/robotic_project/vision/dataset/test/HD/blocks_group2_1.jpg'
legoDetect = LegoDetect()
legoDetect.detect(img_path)
center_list = []
for index, lego in enumerate(legoDetect.lego_list, start=1):
    print(index)
    lego.show()
    center_list.append(lego.center_point)

# Draw center points
img = Image.open(img_path)
draw = ImageDraw.Draw(img)
draw.point(center_list, 'red')
display(img)
# Out:
# Using cache found in /home/toto/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2023-1-12 Python-3.8.10 torch-1.13.1+cu117 CPU
#
# Fusing layers...
# YOLOv5l summary: 267 layers, 46162128 parameters, 0 gradients, 107.8 GFLOPs
# Adding AutoShape...
# <PIL.Image.Image image mode=RGB size=1280x720>
# /home/toto/ros_ws/src/robotic_project/vision/dataset/test/HD/blocks_group2_1.jpg
# img size: 1280 x 720
# 1
# <PIL.Image.Image image mode=RGB size=70x197>
# class = X1-Y4-Z2
# confidence = 0.95
# center_point = (569, 382)
# center_point_uv = (711, 382)
# --> point cloud = ()
#
# -----------------
# 2
# <PIL.Image.Image image mode=RGB size=70x93>
# class = X1-Y2-Z2-TWINFILLET
# confidence = 0.95
# center_point = (531, 377)
# center_point_uv = (749, 377)
# --> point cloud = ()
#
# -----------------
# 3
# <PIL.Image.Image image mode=RGB size=70x102>
# class = X1-Y2-Z2
# confidence = 0.94
# center_point = (790, 359)
# center_point_uv = (490, 359)
# --> point cloud = ()
#
# -----------------
# 4
# <PIL.Image.Image image mode=RGB size=70x113>
# class = X1-Y3-Z2
# confidence = 0.89
# center_point = (744, 364)
# center_point_uv = (536, 364)
# --> point cloud = ()
#
# -----------------
# 5
# <PIL.Image.Image image mode=RGB size=70x198>
# class = X1-Y4-Z1
# confidence = 0.88
# center_point = (608, 383)
# center_point_uv = (672, 383)
# --> point cloud = ()
#
# -----------------
# 6
# <PIL.Image.Image image mode=RGB size=70x110>
# class = X1-Y1-Z2
# confidence = 0.86
# center_point = (716, 365)
# center_point_uv = (564, 365)
# --> point cloud = ()
#
# -----------------
# 7
# <PIL.Image.Image image mode=RGB size=70x140>
# class = X1-Y2-Z2-CHAMFER
# confidence = 0.83
# center_point = (652, 372)
# center_point_uv = (628, 372)
# --> point cloud = ()
#
# -----------------
# 8
# <PIL.Image.Image image mode=RGB size=70x190>
# class = X1-Y4-Z1
# confidence = 0.80
# center_point = (569, 382)
# center_point_uv = (711, 382)
# --> point cloud = ()
#
# -----------------
# 9
# <PIL.Image.Image image mode=RGB size=70x112>
# class = X1-Y2-Z2
# confidence = 0.73
# center_point = (716, 365)
# center_point_uv = (564, 365)
# --> point cloud = ()
#
# -----------------
# 10
# <PIL.Image.Image image mode=RGB size=70x164>
# class = X1-Y3-Z2-FILLET
# confidence = 0.65
# center_point = (684, 377)
# center_point_uv = (596, 377)
# --> point cloud = ()
#
# -----------------
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x720>
