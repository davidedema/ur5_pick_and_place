# %%
# List of difficult img:
# /home/toto/ros_ws/src/robotic_project/vision/dataset/test/HD/blocks_group2_1.jpg
# /home/toto/ros_ws/src/robotic_project/vision/dataset/test/HD/blocks_group2_11.jpg
# /home/toto/ros_ws/src/robotic_project/vision/dataset/test/HD/blocks_group2_36.jpg
# /home/toto/ros_ws/src/robotic_project/vision/dataset/test/HD/block2_3b_i24.jpg
# /home/toto/ros_ws/src/robotic_project/vision/dataset/test/HD/blocks_group2_38.jpg

# %%
from LegoDetect import LegoDetect
from PIL import Image, ImageDraw

img_path = '/home/toto/ros_ws/src/robotic_project/vision/dataset/test/HD/blocks_group2_38.jpg'
legoDetect = LegoDetect(img_path)


# center_list = []
# for index, lego in enumerate(legoDetect.lego_list, start=1):
#     print(index)
#     lego.show()
#     center_list.append(lego.center_point)

# Draw center points
# img = Image.open(img_path)
# draw = ImageDraw.Draw(img)
# draw.point(center_list, 'red')
# display(img)
# Out:
# Using cache found in /home/toto/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2023-1-12 Python-3.8.10 torch-1.13.1+cu117 CPU
#
# Fusing layers...
# YOLOv5l summary: 267 layers, 46162128 parameters, 0 gradients, 107.8 GFLOPs
# Adding AutoShape...
# <PIL.Image.Image image mode=RGB size=1280x720>
# /home/toto/ros_ws/src/robotic_project/vision/dataset/test/HD/blocks_group2_38.jpg
# img size: 1280 x 720
# Detected 8 object(s)
#
# 1
# <PIL.Image.Image image mode=RGB size=70x41>
# class = X1-Y4-Z2
# id = 8
# confidence = 0.97
# center_point = (697, 351)
# center_point_uv = (583, 351)
# --> point cloud = ()
# --> point world = ()
#
# 2
# <PIL.Image.Image image mode=RGB size=70x45>
# class = X1-Y3-Z2
# id = 5
# confidence = 0.97
# center_point = (758, 371)
# center_point_uv = (522, 371)
# --> point cloud = ()
# --> point world = ()
#
# 3
# <PIL.Image.Image image mode=RGB size=70x62>
# class = X1-Y2-Z2-CHAMFER
# id = 3
# confidence = 0.97
# center_point = (755, 451)
# center_point_uv = (525, 451)
# --> point cloud = ()
# --> point world = ()
#
# 4
# <PIL.Image.Image image mode=RGB size=70x68>
# class = X1-Y2-Z2
# id = 2
# confidence = 0.96
# center_point = (655, 461)
# center_point_uv = (625, 461)
# --> point cloud = ()
# --> point world = ()
#
# 5
# <PIL.Image.Image image mode=RGB size=70x66>
# class = X1-Y2-Z2-TWINFILLET
# id = 4
# confidence = 0.96
# center_point = (631, 413)
# center_point_uv = (649, 413)
# --> point cloud = ()
# --> point world = ()
#
# 6
# <PIL.Image.Image image mode=RGB size=70x46>
# class = X1-Y3-Z2-FILLET
# id = 6
# confidence = 0.96
# center_point = (602, 377)
# center_point_uv = (678, 377)
# --> point cloud = ()
# --> point world = ()
#
# 7
# <PIL.Image.Image image mode=RGB size=70x112>
# class = X1-Y1-Z2
# id = 0
# confidence = 0.90
# center_point = (555, 492)
# center_point_uv = (725, 492)
# --> point cloud = ()
# --> point world = ()
#
# 8
# <PIL.Image.Image image mode=RGB size=70x163>
# class = X1-Y4-Z1
# id = 7
# confidence = 0.85
# center_point = (509, 438)
# center_point_uv = (771, 438)
# --> point cloud = ()
# --> point world = ()
#
# Draw RegionOfInterest
# Detecting RegionOfInterest...
# <PIL.Image.Image image mode=RGB size=1280x720>
# /home/toto/ros_ws/src/robotic_project/vision/scripts/log/img_ROI.png
# img size: 1280 x 720
# Detected 4 object(s)
#
# 1
# <PIL.Image.Image image mode=RGB size=70x43>
# class = X1-Y3-Z2
# id = 5
# confidence = 0.96
# center_point = (756, 371)
# center_point_uv = (524, 371)
# --> point cloud = ()
# --> point world = ()
#
# 2
# <PIL.Image.Image image mode=RGB size=70x68>
# class = X1-Y2-Z2-TWINFILLET
# id = 4
# confidence = 0.91
# center_point = (630, 414)
# center_point_uv = (650, 414)
# --> point cloud = ()
# --> point world = ()
#
# 3
# <PIL.Image.Image image mode=RGB size=70x70>
# class = X1-Y2-Z2
# id = 2
# confidence = 0.91
# center_point = (655, 461)
# center_point_uv = (625, 461)
# --> point cloud = ()
# --> point world = ()
#
# 4
# <PIL.Image.Image image mode=RGB size=70x68>
# class = X1-Y2-Z2-TWINFILLET
# id = 4
# confidence = 0.75
# center_point = (757, 450)
# center_point_uv = (523, 450)
# --> point cloud = ()
# --> point world = ()
#
# Draw RegionOfInterest
# ROI AUTO...
# Detecting RegionOfInterest...
# <PIL.Image.Image image mode=RGB size=1280x720>
# /home/toto/ros_ws/src/robotic_project/vision/scripts/log/img_ROI.png
# img size: 1280 x 720
# Detected 0 object(s)
#
# Draw RegionOfInterest
# Detecting RegionOfInterest...
# <PIL.Image.Image image mode=RGB size=1280x720>
# /home/toto/ros_ws/src/robotic_project/vision/scripts/log/img_ROI.png
# img size: 1280 x 720
# Detected 8 object(s)
#
# 1
# <PIL.Image.Image image mode=RGB size=70x44>
# class = X1-Y3-Z2
# id = 5
# confidence = 0.97
# center_point = (757, 371)
# center_point_uv = (523, 371)
# --> point cloud = ()
# --> point world = ()
#
# 2
# <PIL.Image.Image image mode=RGB size=70x41>
# class = X1-Y4-Z2
# id = 8
# confidence = 0.97
# center_point = (696, 351)
# center_point_uv = (584, 351)
# --> point cloud = ()
# --> point world = ()
#
# 3
# <PIL.Image.Image image mode=RGB size=70x62>
# class = X1-Y2-Z2-CHAMFER
# id = 3
# confidence = 0.97
# center_point = (756, 450)
# center_point_uv = (524, 450)
# --> point cloud = ()
# --> point world = ()
#
# 4
# <PIL.Image.Image image mode=RGB size=70x66>
# class = X1-Y2-Z2-TWINFILLET
# id = 4
# confidence = 0.96
# center_point = (631, 413)
# center_point_uv = (649, 413)
# --> point cloud = ()
# --> point world = ()
#
# 5
# <PIL.Image.Image image mode=RGB size=70x43>
# class = X1-Y3-Z2-FILLET
# id = 6
# confidence = 0.96
# center_point = (602, 377)
# center_point_uv = (678, 377)
# --> point cloud = ()
# --> point world = ()
#
# 6
# <PIL.Image.Image image mode=RGB size=70x70>
# class = X1-Y2-Z2
# id = 2
# confidence = 0.96
# center_point = (655, 461)
# center_point_uv = (625, 461)
# --> point cloud = ()
# --> point world = ()
#
# 7
# <PIL.Image.Image image mode=RGB size=70x107>
# class = X1-Y2-Z2
# id = 2
# confidence = 0.82
# center_point = (555, 492)
# center_point_uv = (725, 492)
# --> point cloud = ()
# --> point world = ()
#
# 8
# <PIL.Image.Image image mode=RGB size=70x166>
# class = X1-Y4-Z1
# id = 7
# confidence = 0.81
# center_point = (510, 439)
# center_point_uv = (770, 439)
# --> point cloud = ()
# --> point world = ()
